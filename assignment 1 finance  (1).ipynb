# %%
import pandas as pd
import numpy as np

# %%
nifty=pd.read_csv("nifty50.csv")
nifty
# Out:
#             Date  ADANIPORTS.NS    TECHM.NS  BRITANNIA.NS       TCS.NS  \
# 0     01-01-2016     267.549988  520.049988   1493.199951  1208.199951
# 1     04-01-2016     257.950012  516.400024   1486.300049  1184.800049
# 2     05-01-2016     255.699997  521.900024   1483.349976  1174.469971
# 3     06-01-2016     251.800003  525.099976   1500.849976  1190.800049
# 4     07-01-2016     245.000000  510.799988   1473.280029  1185.619995
# ...          ...            ...         ...           ...          ...
# 1277         NaN            NaN         NaN           NaN          NaN
# 1278         NaN            NaN         NaN           NaN          NaN
# 1279         NaN            NaN         NaN           NaN          NaN
# 1280         NaN            NaN         NaN           NaN          NaN
# 1281         NaN            NaN         NaN           NaN          NaN
#
#       SUNPHARMA.NS     INFY.NS  HINDALCO.NS   DRREDDY.NS  HCLTECH.NS  ...  \
# ...

# %%
nifty.drop("HDFCLIFE.NS",inplace=True,axis=1)
nifty.drop("SBILIFE.NS",inplace=True,axis=1)
new_data=nifty.dropna()
new_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-cac4c06b91e5> in <module>
# ----> 1 nifty.drop("HDFCLIFE.NS",inplace=True,axis=1)
#       2 nifty.drop("SBILIFE.NS",inplace=True,axis=1)
#       3 new_data=nifty.dropna()
#       4 new_data
#
# NameError: name 'nifty' is not defined

# %%
new_data.set_index("Date",inplace=True)
new_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-07bc5dac952d> in <module>
# ----> 1 new_data.set_index("Date",inplace=True)
#       2 new_data
#
# ~\anaconda3pictures\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['Date'] are in the columns"

# %%
name=list(new_data)
name
# Out:
# ['ADANIPORTS.NS',
#  'TECHM.NS',
#  'BRITANNIA.NS',
#  'TCS.NS',
#  'SUNPHARMA.NS',
#  'INFY.NS',
#  'HINDALCO.NS',
#  'DRREDDY.NS',
#  'HCLTECH.NS',
#  'HINDUNILVR.NS',
#  'TATASTEEL.NS',
#  'NTPC.NS',
#  'CIPLA.NS',
#  'ITC.NS',
#  'BPCL.NS',
#  'WIPRO.NS',
#  'JSWSTEEL.NS',
#  'GAIL.NS',
#  'DIVISLAB.NS',
#  'ULTRACEMCO.NS',
#  'NESTLEIND.NS',
#  'ASIANPAINT.NS',
#  'EICHERMOT.NS',
#  'IOC.NS',
#  'GRASIM.NS',
#  'BAJAJ-AUTO.NS',
#  'HDFC.NS',
#  'M&M.NS',
#  'UPL.NS',
#  'SHREECEM.NS',
#  'MARUTI.NS',
#  'TITAN.NS',
#  'BAJAJFINSV.NS',
#  'KOTAKBANK.NS',
#  'COALINDIA.NS',
#  'BHARTIARTL.NS',
#  'HEROMOTOCO.NS',
#  'LT.NS',
#  'ONGC.NS',
#  'SBIN.NS',
#  'RELIANCE.NS',
#  'BAJFINANCE.NS',
#  'AXISBANK.NS',
#  'HDFCBANK.NS',
#  'TATAMOTORS.NS',
#  'ICICIBANK.NS',
#  'POWERGRID.NS',
#  'INDUSINDBK.NS']

# %%
def CAGR(new_data,name):
    initial_price = new_data[name].iloc[0]
    final_price= new_data[name].iloc[-1]
    no_of_year=4
    cagr =pow((final_price/initial_price),0.25)- 1
    
    return cagr

# %%
def Volatility(new_data,name):
    new_data[name]=new_data[name].pct_change()
    vol=data[name].std()*np.sqrt(252)
    return vol

# %%
def sharpe(x,y,rf):
    
    Sharpe_Ratio = (x-rf) / y
    
    
    return Sharpe_Ratio

# %%
cagr = []
vol = []
Sharpe_Ratio= []
rf = 0.06
for i in range(len(name)):
    x = CAGR(new_data, name[i])
    y = Volatility(new_data, name[i])
    z = sharpe(x,y,rf)
    cagr.append(x)
    vol.append(y)
    Sharpe_Ratio.append(z)
print(cagr)
print(vol)
print(Sharpe_Ratio)
# Out:
# [0.1595887962668434, 0.1696051012367188, 0.24402902974227136, 0.24068391668627775, -0.07682943788109364, 0.2277854769024268, 0.29740156418103036, 0.13753837706555117, 0.22299354511598457, 0.29317210700872853, 0.2728208472308853, -0.046940498147527876, 0.0576172417633567, -0.010862357462357197, 0.06281361121341744, 0.1664137648998545, 0.3934494964346509, 0.04339019838923264, 0.3483053909449978, 0.16979501490466875, 0.3352665031815807, 0.33179633085462634, 0.0986612066315169, -0.042736429198045545, 0.12285695355972348, 0.08144249747719567, 0.19410833397733285, 0.033066775539455806, 0.12266761031073603, 0.2051567928616589, 0.1332227712291405, 0.45253484666152954, 0.4556281998017342, 0.2870559896204057, -0.20202022387194152, 0.12997157939720938, 0.03731718331697076, 0.10633828366227815, -0.1289887826478201, 0.04815377884776484, 0.40624210286333406, 0.7167696387431843, 0.08367162661509053, 0.27449093470820096, -0.17759373086733032, 0.2230882132881351, 0.0772037973007087, -0.01837110342091
# ...

# %%
data_tuple=list(zip(name,Sharpe_Ratio))
from heapq import nlargest
from operator import itemgetter
TOP_15_STOCKS=nlargest(15, data_tuple, key=itemgetter(1))
print(pd.DataFrame(TOP_15_STOCKS, columns=['Company Name', 'Sharpe Ratio']))
# Out:
#      Company Name  Sharpe Ratio
# 0     HINDALCO.NS      0.000307
# 1     JSWSTEEL.NS      0.000297
# 2        WIPRO.NS      0.000155
# 3    ICICIBANK.NS      0.000115
# 4    TATASTEEL.NS      0.000109
# 5   ADANIPORTS.NS      0.000097
# 6      HCLTECH.NS      0.000089
# 7        TITAN.NS      0.000075
# 8         INFY.NS      0.000063
# 9     HDFCBANK.NS      0.000057
# 10   POWERGRID.NS      0.000054
# 11  BHARTIARTL.NS      0.000053
# 12       TECHM.NS      0.000048
# 13  ASIANPAINT.NS      0.000047
# 14    RELIANCE.NS      0.000046
